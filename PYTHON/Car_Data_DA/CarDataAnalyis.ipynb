# %%
import pandas as pd
data = pd.read_csv("2. Cars Data1 (1).csv")
data
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [432 rows x 15 columns]

# %%
datacopy = data.copy()
datacopy.head()
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
# 2  Acura         TSX 4dr  Sedan   Asia  ...        29.0  3230.0     105.0   183.0
# 3  Acura          TL 4dr  Sedan   Asia  ...        28.0  3575.0     108.0   186.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...        24.0  3880.0     115.0   197.0
#
# [5 rows x 15 columns]

# %%
datacopy.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
#For removing empty rows in the csv file
datacopy = datacopy.dropna(how='all')
datacopy.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
#For filling isnan with mean value of the column
datacopy['Cylinders'].fillna(datacopy['Cylinders'].mean(),inplace = True)
datacopy.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
CarMake = datacopy['Make'].value_counts()
CarMake
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
datacopy['Make'].value_counts().nlargest(5).plot(kind='bar', color='green')
plt.title('Number of Cars by Make')
plt.xlabel('Make')
plt.ylabel('Number of Cars')
plt.show()

# %%
datacopy['Origin'].unique()
# Out:
# array(['Asia', 'Europe', 'USA'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(3,5))
datacopy['Origin'].value_counts().plot(kind='bar', color='red')
plt.title('Number of Cars by Origin')
plt.xlabel('Origin')
plt.ylabel('Number of Cars')
plt.show()

# %%
datacopy['Price'] = datacopy['Invoice'].str.replace('$',"")
datacopy.head()
# Out:
# /var/folders/w0/69r_3lm51332rmxrb325l0xr0000gp/T/ipykernel_35587/3951818969.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   datacopy['Price'] = datacopy['Invoice'].str.replace('$',"")
#     Make           Model   Type Origin  ...  Weight Wheelbase Length    Price
# 0  Acura             MDX    SUV   Asia  ...  4451.0     106.0  189.0  33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...  2778.0     101.0  172.0  21,761
# 2  Acura         TSX 4dr  Sedan   Asia  ...  3230.0     105.0  183.0  24,647
# 3  Acura          TL 4dr  Sedan   Asia  ...  3575.0     108.0  186.0  30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...  3880.0     115.0  197.0  39,014
#
# [5 rows x 16 columns]

# %%
datacopy.shape
# Out:
# (428, 16)

# %%
datacopy['Price'] = datacopy['Price'].str.replace(',','')
datacopy['Price'] = datacopy['Price'].astype(int)
datacopy['Price'].dtype
# Out:
# dtype('int64')

# %%
datacopy.head()
# Out:
#     Make           Model   Type Origin  ...  Weight Wheelbase Length  Price
# 0  Acura             MDX    SUV   Asia  ...  4451.0     106.0  189.0  33337
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...  2778.0     101.0  172.0  21761
# 2  Acura         TSX 4dr  Sedan   Asia  ...  3230.0     105.0  183.0  24647
# 3  Acura          TL 4dr  Sedan   Asia  ...  3575.0     108.0  186.0  30299
# 4  Acura      3.5 RL 4dr  Sedan   Asia  ...  3880.0     115.0  197.0  39014
#
# [5 rows x 16 columns]

# %%
average_price = datacopy['Price'].mean()
average_price
# Out:
# 30014.70093457944

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the average price for each make
average_price_by_make = datacopy.groupby('Make')['Price'].mean()

# Select the top 5 makes with the highest average prices
top_5_makes = average_price_by_make.nlargest(5).index

# Filter the data for the top 5 makes
top_5_data = datacopy[datacopy['Make'].isin(top_5_makes)]

# Create a bar plot for the top 5 makes
plt.figure(figsize=(12, 8))
sns.barplot(x='Make', y='Price', data=top_5_data, hue='Origin', palette='muted')

# Set labels and title
plt.title('Top 5 Car Makes by Average Price', fontsize=20)
plt.xlabel('Make', fontsize=10)
plt.ylabel('Price', fontsize=10)
plt.legend(loc='upper left', fontsize=14)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
datacopy = datacopy.sort_values(by='Price',ascending=False)
datacopy_15 = datacopy.head(15)

# Create a bar plot
sns.barplot(x = 'Make', y = 'Price', data = datacopy_15, hue = 'Origin',palette='Set1')


# Set labels and titles
plt.title("Price Distribution of Top 7 Car Types by Make and Origin", fontsize=20)
plt.xlabel("Make",fontsize=14)
plt.ylabel("Price",fontsize=14)
plt.xticks(rotation=90)
plt.legend(loc='upper left',fontsize=14)
plt.show()

# %%
sns.set_style("whitegrid")
# create a bar plot with larger size
plt.figure(figsize=(13,7))
sns.barplot(x = 'Make', y = 'Price', data = datacopy_15, hue = 'Origin', palette='Blues')

#set labels and titles
plt.title("Price Distribution by No. of Make", fontsize=16)
plt.xlabel("Make",fontsize=8)
plt.ylabel("Price",fontsize=8)
plt.show()

# %%
datacopy_grouped = datacopy.groupby('Make').mean()[['Cylinders']]
datacopy_grouped.sort_values(by='Cylinders',ascending=False,inplace=True)
top_10_car_types = datacopy_grouped.head(10)
top_10_car_types
# Out:
# /var/folders/w0/69r_3lm51332rmxrb325l0xr0000gp/T/ipykernel_35587/1461149689.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datacopy_grouped = datacopy.groupby('Make').mean()[['Cylinders']]
#                Cylinders
# Make
# Hummer          8.000000
# Cadillac        7.750000
# Lincoln         7.555556
# Jaguar          7.500000
# Land Rover      7.333333
# Mercedes-Benz   7.076923
# Lexus           6.909091
# Mercury         6.888889
# GMC             6.750000
# Infiniti        6.750000

# %%
plt.figure(figsize=(12,8))
#create a bar plot of the average cylinder size by top 10 car types
sns.barplot(x=top_10_car_types.index, y='Cylinders', palette='PuBu', data=top_10_car_types)

#set the title and labels
plt.title("Average Cylinder Size by Top 10 Car Types", fontsize=16)
plt.xlabel("Car Type")
plt.ylabel("Average Cylinder Size")
plt.xticks(rotation=90) # to rotate x_axis label by 90 degrees
plt.show()

# %%
# Create a bar plot
sns.lmplot(x = 'EngineSize', y = 'Horsepower', data = datacopy, hue = 'Origin',palette='Set1')


# Set labels and titles
plt.title("Relationship between EngineSize and HorsePower", fontsize=20)
plt.xlabel("Engine Size",fontsize=14)
plt.ylabel("Horsepower",fontsize=14)
plt.xticks(rotation=90)
plt.legend(loc='upper left',fontsize=14)
plt.show()
